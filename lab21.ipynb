# %%
# !git clone https://github.com/hieutrungdao/Day21-Track3-Finetuning-Lab.git
# %cd Day21-Track3-Finetuning-Lab
# !pip install -q -r requirements.txt
# Out:
# Cloning into 'Day21-Track3-Finetuning-Lab'...
# remote: Enumerating objects: 348, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 348 (delta 52), reused 52 (delta 52), pack-reused 287 (from 1)
# Receiving objects: 100% (348/348), 242.16 KiB | 12.75 MiB/s, done.
# Resolving deltas: 100% (218/218), done.
# /kaggle/working/Day21-Track3-Finetuning-Lab
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 106.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.8/925.8 kB 50.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.8/775.8 kB 28.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.2/389.2 kB 23.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 93.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 MB 50.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.0/516.0 kB 36.2 MB/s eta 0:00:00

# %%
import os
os.environ["COMPUTE_TIER"] = "T4"
# !python scripts/verify.py --smoke
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 4.82s
#
# 6 passed · 0 warnings · 1 failures
#
# Not ready to submit — fix the FAILs above.

# %%
# Sửa file train.py trên Kaggle để đổi chunked_nll thành nll
file_path = "/kaggle/working/Day21-Track3-Finetuning-Lab/src/labkit/train.py"

with open(file_path, "r", encoding="utf-8") as f:
    code = f.read()

# Thay thế cấu hình loss_type gây lỗi
code = code.replace('loss_type="chunked_nll"', 'loss_type="nll"')

with open(file_path, "w", encoding="utf-8") as f:
    f.write(code)

print("✅ Đã cập nhật xong file src/labkit/train.py!")
# Out:
# ✅ Đã cập nhật xong file src/labkit/train.py!

# %%
# !python scripts/colab_run.py nb1 nb2 nb3 nb4 nb5
# Out:
# tier=T4  mask=assistant-only  eval_limit=full
#
# ...
# NB1 — data, chat template & loss mask
# ...
# tier=T4  model=unsloth/Qwen3.5-4B  max_length=1024
# 250 mẫu huấn luyện
# {
#   "instruction": "Phân loại ticket chăm sóc khách hàng sau thành JSON với đúng 4 khóa: intent, urgency, product, sentiment. Chỉ trả về JSON, không giải thích.\n\nintent thuộc: doi_tra | van_chuyen | hoan_tien | san_pham_loi | hoi_thong_tin\nurgency thuộc: cao | trung_binh | thap\nsentiment thuộc: tieu_cuc | trung_tinh | tich_cuc\nproduct: tên sản phẩm xuất hiện trong ticket.",
#   "input": "Alo sh
# ...
# config.json: 2.76kB [00:00, 6.75MB/s]
# tokenizer_config.json: 15.7kB [00:00, 25.5MB/s]
# vocab.json: 5.23MB [00:00, 61.4MB/s]
# merges.txt: 3.35MB [00:00, 113MB/s]
# tokenizer.json: 100%|██████████████████████| 20.0M/20.0M [00:00<00:00, 23.8MB/s]
# ...
# special_tokens_map.json: 100%|█████████████████| 876/876 [00:00<00:00, 2.50MB/s]
# chat_template.jinja: 7.99kB [00:00, 16.1MB/s]
# eos_token: <|im_end|>
# ...

# %%
# !python scripts/verify.py
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       4 failed, 114 passed in 2.33s
# [  ok  ] results/template_check.json
# [  ok  ] results/mask_proof.json
# [  ok  ] results/token_stats.json
# [  ok  ] results/baselines_frozen.json
# [  ok  ] results/runs.csv
# [  ok  ] results/verdict.json
# [  ok  ] results/autopsy.json
# [  ok  ] submission/REPORT.md
# [ FAIL ] REPORT.md filled in                              6 placeholders still present (<điền>, <paste>, ...) — this is still the template
# [  ok  ] mask proof asserts
# [  ok  ] full eval set used                               50 target items
# ...
