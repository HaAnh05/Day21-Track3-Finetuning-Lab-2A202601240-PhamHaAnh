# %%
# !git clone https://github.com/HaAnh05/Day21-Track3-Finetuning-Lab-2A202601240-PhamHaAnh.git
# %cd Day21-Track3-Finetuning-Lab-2A202601240-PhamHaAnh
# !pip install -q -r requirements.txt
# Out:
# Cloning into 'Day21-Track3-Finetuning-Lab-2A202601240-PhamHaAnh'...
# remote: Enumerating objects: 384, done.
# remote: Counting objects: 100% (264/264), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 384 (delta 212), reused 183 (delta 183), pack-reused 120 (from 2)
# Receiving objects: 100% (384/384), 4.00 MiB | 18.51 MiB/s, done.
# Resolving deltas: 100% (230/230), done.
# /kaggle/working/Day21-Track3-Finetuning-Lab-2A202601240-PhamHaAnh
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 112.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.8/925.8 kB 54.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.8/775.8 kB 49.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.2/389.2 kB 28.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 96.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 MB 50.2 MB/s eta 0:00:00
# ...

# %%
import os
os.environ["COMPUTE_TIER"] = "T4"

# Chạy NB1 (tạo split) -> NB3 (train adapter) -> NB6 (merge & kiểm tra)
# !python scripts/colab_run.py nb1 nb3 nb6
# Out:
# tier=T4  mask=assistant-only  eval_limit=full
#
# ...
# NB1 — data, chat template & loss mask
# ...
# tier=T4  model=unsloth/Qwen3.5-4B  max_length=1024
# 250 mẫu huấn luyện
# {
#   "instruction": "Phân loại ticket chăm sóc khách hàng sau thành JSON với đúng 4 khóa: intent, urgency, product, sentiment. Chỉ trả về JSON, không giải thích.\n\nintent thuộc: doi_tra | van_chuyen | hoan_tien | san_pham_loi | hoi_thong_tin\nurgency thuộc: cao | trung_binh | thap\nsentiment thuộc: tieu_cuc | trung_tinh | tich_cuc\nproduct: tên sản phẩm xuất hiện trong ticket.",
#   "input": "Alo sh
# config.json: 2.76kB [00:00, 10.1MB/s]
# ...
# tokenizer_config.json: 15.7kB [00:00, 35.9MB/s]
# vocab.json: 5.23MB [00:00, 107MB/s]
# merges.txt: 3.35MB [00:00, 119MB/s]
# tokenizer.json: 100%|██████████████████████| 20.0M/20.0M [00:00<00:00, 45.9MB/s]
# ...
# special_tokens_map.json: 100%|█████████████████| 876/876 [00:00<00:00, 5.63MB/s]
# chat_template.jinja: 7.99kB [00:00, 21.0MB/s]
# eos_token: <|im_end|>
# ...

# %%
# !cat results/merge_check.json
# Out:
# {
#   "before_merge": 0.0,
#   "after_merge": 0.0,
#   "delta": 0.0,
#   "tolerance": 0.01,
#   "n": 50
# }
